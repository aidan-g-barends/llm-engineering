# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports

from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

ollama = OpenAI(
    base_url = "http://localhost:11434/v1",
    api_key = "ollama"
)

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming

# %%
# Get Llama 3.2 to answer

response  = ollama.chat.completions.create(
    model = MODEL_LLAMA,
    messages=[
        {
            "role": "user",
            "content": question
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# This line of code is written in Python and utilizes the `yield from` syntax. Let's break it down:
#
# 1. `{book.get("author") for book in books if book.get("author")}`: This is a dictionary comprehension that filters a list of dictionaries (`books`) based on a condition. It returns an iterator (generator) over keys from each of the dictionaries in `books` where the key value exists and matches a certain pattern.
#
# 2. `yield from`: This keyword is used to yield items from another generator or object, but here it's used in conjunction with dictionary comprehensions for more complex iteration logic. It allows us to yield values from different generators while still allowing control flow to continue at the point after which `yield from` is encountered.
#
# So when combined together, `{book.get("author") for book in books if book.get("author")} yields all unique keys from any of dictionaries where a given key exist. 'gets' can handle nested dictionaries too.
#
#
# ```python
# books = [
#     {"id": 1, "title": "The Godfather", "author": "Francis Ford Coppola", "publisher": {"name": "Alfred A. Knopf"}},
#     {"id": 2, "title": "Psycho", "author": "Robert Bloch"},
#     {"id": 3, "title": "Schindler's List", "author": "Steinmayer, Thomas", "publisher": {}}
# ]
#
# def get_authors():
#     return {book.get("author") for book in books if book.get("author")
#
# }
# for key in get_authors():
#     print(key)
# ```
#
# This will output:
# 'Francis Ford Coppola'
# 'Robert Bloch'
#
# Note that the dictionary values are yielded here only when they contain a non-empty value. In practice, you can probably always assume that there is an existing attribute unless explicitly otherwise stated; hence `book.get("author")` may simply be used as just `book["author"]`.
